# %% [markdown]
# # Run Experiments: Q-Learning vs Expected Sarsa
#
# This notebook will run training and evaluation on the Cliff World environment using Q-Learning and Expected Sarsa.
#
# Ensure that `q_learning_agent.py`, `expected_sarsa_agent.py`, and `cliffworld_env.py` are in the same directory.

# %%
# Example usage stub
from cliffworld_env import Environment

env = Environment()
state = env.reset()
done = False
while not done:
    action = 3  # Always move right (placeholder)
    next_state, reward, done = env.step(action)
    print(f"State: {state} -> Next: {next_state}, Reward: {reward}, Done: {done}")
    state = next_state
